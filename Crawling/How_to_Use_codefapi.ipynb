# %% [markdown]
# # 토큰 요청

# %% [markdown]
# $ python -m pip install easycodefpy

# %%
from easycodefpy import Codef, ServiceType

demo_client_id = 'b27f40e4-241e-40fb-93b6-3e0ebd8e50d5'
demo_client_secret = '77e9beb8-0c3e-43b7-8c9a-db3494a135d9'

# client_id = 'ef27cfaa-10c1-4470-adac-60ba476273f9'
# client_secret = '83160c33-9045-4915-86d8-809473cdf5c3'

public_key = ''

# 코드에프 인스턴스 생성
codef = Codef()
codef.public_key = public_key

# 데모 클라이언트 정보 설정
# - 데모 서비스 가입 후 코드에프 홈페이지에 확인 가능(https://codef.io/#/account/keys)
# - 데모 서비스로 상품 조회 요청시 필수 입력 항목
codef.set_demo_client_info(demo_client_id, demo_client_secret)

# 정식 클라이언트 정보 설정
# - 정식 서비스 가입 후 코드에프 홈페이지에 확인 가능(https://codef.io/#/account/keys)
# - 정식 서비스로 상품 조회 요청시 필수 입력 항목
# codef.set_client_info(client_id, client_secret)

# 토큰 발급 요청
token = codef.request_token(ServiceType.SANDBOX)

# 결과 출력
print(token)
# Out:
# eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..KP8DEqEo8lMwHGdN-7AeuZPj15drQducxDWG8kYd-DycdOFOvw2GP0RMpSYcy1n88kPLaEcTMupy50SvDzx_Zco9T_FMRZrYnvY9WpinjO9JsrQRbaHIgJjpCj1x05Y-WIE7JVT58s8hCOPnSn85dP7xsMblkbdDzRV9bPQxKiIAaoULRVzFxUU8zlK8aOGE1fZhp-xy_M8dCxOWXKqadHKROZGkEuEKvwpTlWWZEZFjXL0w9h6pCoBQp70vcXHe5t4WOM4x8l8Kz9Ik4xjUVQEPMu8hb5D-YC4VlNFvmrEHQMCrsoNoV8bRD1ZAw89MhActG32y5JYXm77GQYfyaQ

# %% [markdown]
# # 커넥티드 아이디

# %%
# import requests, json, base64
# import urllib

# def stringToBase64(s):
#     return base64.b64encode(s.encode('utf-8'))

# def request_token(url, client_id, client_secret):
#     authHeader = stringToBase64(client_id + ':' + client_secret).decode("utf-8")

#     headers = {
#         'Acceppt': 'application/json',
#         'Content-Type': 'application/x-www-form-urlencoded',
#         'Authorization': 'Basic ' + authHeader
#         }

#     response = requests.post(url, headers = headers, data = 'grant_type=client_credentials&scope=read')

#     print(response.status_code)
#     print(response.text)

#     return response

# token_url = 'https://oauth.codef.io/oauth/token'
# response_oauth = request_token(token_url, demo_client_id, demo_client_secret)
# if response_oauth.status_code == 200:
#     dict = json.loads(response_oauth.text)
#     # reissue_token
#     token = dict['access_token']

#     print('access_token = ' + token)
# else:
#     print('토큰발급 오류')
# Out:
# 200
# {"access_token":"eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..k8Q0UspHHRZlFzr7GDvjo1SC79VXQ8JphKaWwCQfPCzxtbcJfRN_tDev02Xd5GeEhFEiX1AQMrZ-QgtS96WPTpx4409noodsFf-32DgY6_2TWXoES1qYszfhr-GSU86zcu0LB95dx880ULOof1cIrvdKpbYeJkP8wA9HrCmkHuJWWgHuRgwJQsVjDayjGU_JegtppUxxjbtJ0EJucS6MwM7ehVsbdp5wZ92Y6AwacMRgIZuI8dPrHjVBBK8DUiTjklYZvh19N37PIHx1LEVQ-l4xi1jetEFGZziSoUSTEyDok0aZYwAaKaarBvY0pcSJgFLSZtLVtqSYR4LPHRjo6Q","token_type":"bearer","expires_in":604799,"scope":"read"}
# ...

# %% [markdown]
# # 커넥티드 아이디 등록

# %%
...
from easycodefpy import Codef, ServiceType, encrypt_rsa


# 요청 파라미터 설정
# - 계정관리 파라미터를 설정(https://developer.codef.io/cert/account/cid-overview)
account_list = []
account = {
    'countryCode':  'KR',
    'businessType': 'BK',
    'clientType':   'P',
    'organization': '0020',
    'loginType':    '1',
    'id':           "user_id",
}

# 비밀번호 설정
pwd = encrypt_rsa("password", codef.public_key)
account['password'] = pwd
account_list.append(account)

parameter = {
    'accountList': account_list,
}

# 요청
res = codef.create_account(ServiceType.SANDBOX, parameter)
print(res)
# Out:
# {"result": {"code": "CF-00000", "extraMessage": "", "message": "정상", "transactionId": "e7ede83e-8130-4f5a-a269-8441e124ad15"}, "data": {"successList": [{"clientType": "P", "code": "CF-00000", "loginType": "1", "countryCode": "KR", "organization": "0020", "extraMessage": "", "businessType": "BK", "message": "정상"}], "errorList": [], "connectedId": "byi1wYwD40k8hEIiXl6bRF"}}

# %% [markdown]
# # 상품요청

# %%
from easycodefpy import Codef, ServiceType

# demo_client_id = ''
# demo_client_secret = ''

# client_id = ''
# client_secret = ''

# public_key = ''

# 코드에프 인스턴스 생성
# codef = Codef()
# codef.public_key = public_key

# 데모 클라이언트 정보 설정
# - 데모 서비스 가입 후 코드에프 홈페이지에 확인 가능(https://codef.io/#/account/keys)
# - 데모 서비스로 상품 조회 요청시 필수 입력 항목
# codef.set_demo_client_info(demo_client_id, demo_client_secret)

# 정식 클라이언트 정보 설정
# - 정식 서비스 가입 후 코드에프 홈페이지에 확인 가능(https://codef.io/#/account/keys)
# - 정식 서비스로 상품 조회 요청시 필수 입력 항목
# codef.set_client_info(client_id, client_secret)


# 요청 파라미터 설정
# - 각 상품별 파라미터를 설정(https://developer.codef.io/products)
# parameter = {
#     'connectedId': 'byi1wYwD40k8hEIiXl6bRF',
#     'organization': '0020',
# }

# #sms 인증
# parameter = {
#     "organization": "0020",
#     "loginType": "2",
#     "certType": "1",
#     # "certFile": "BASE64로 Encoding된 인증서 der파일 문자열",
#     # "keyFile": "BASE64로 Encoding된 인증서 key파일 문자열",
#     # "certPassword": "RSA암호화된 비밀번호",
#     "identity": "주민등록번호",
#     "loginTypeLevel": "",
#     "userName": "박진일",
#     "phoneNo": "전화번호",
#     "authMethod": "",
#     "telecom": "",
#     "timeout": "",
#     "startDate": "",
#     "secureNoYN": "",
#     "reqChildYN": "0"
# }

# 간편인증
parameter = {
    "organization": "0020",
    "loginType": "5",
    "loginTypeLevel": "1",
    "identity": "주민번호",
    "userName": "이름",
    "phoneNo": "전화번호",
    "startDate": "",
    "telecom": "",
    "id": "",
    "detailYN":"1",
    "reqChildYN": "0"
}

# 코드에프 정보 조회 요청
# - 서비스타입(0:정식, 1:데모, 2:샌드박스)
# 개인 보유계좌 조회 (https://developer.codef.io/products/bank/common/p/account)
product_url = "/v1/kr/public/hw/hira-list/my-medicine"
res = codef.request_product(product_url, ServiceType.DEMO, parameter)
print(res)
# Out:
# {"result": {"code": "CF-03002", "extraMessage": "API 요청 처리가 정상 진행 중입니다. 추가 정보를 입력하세요.", "message": "성공", "transactionId": "670cab29ec82b80146b46567"}, "data": {"jobIndex": 0, "threadIndex": 0, "jti": "670cab29ec82b80146b46567", "twoWayTimestamp": 1728883499663, "continue2Way": true, "extraInfo": {"commSimpleAuth": ""}, "method": "simpleAuth"}, "reqChildYN": "0"}

# %%
parameter = {
    "simpleAuth": "1",
    "is2Way": True,
    "organization":'0020',
    "twoWayInfo": {
        "jobIndex": 0,
        "threadIndex": 0,
        "jti": "670cab29ec82b80146b46567",
        "twoWayTimestamp": 1728883499663
    }
}
res = codef.request_certification(product_url, ServiceType.DEMO, parameter)
print(res)
# Out:
# {"result": {"code": "CF-00000", "extraMessage": "", "message": "성공", "transactionId": "670cab29ec82b80146b46567"}, "data": [{"resDrugList": [{"resNumber": "1", "resDrugCode": "645701300", "resDrugName": "헤브론에프정", "resIngredients": "ivy leaf 30% ethanol dried ext.(5~7.5→1) (as hederacoside C 2.5mg)", "resContent": "1정", "resOneDose": "1", "resDailyDosesNumber": "3", "resTotalDosingdays": "6", "resPrescribeDrugEffect": "진해거담제", "resDrugImageLink": "https://biz.kpis.or.kr/kpis_biz/images/new/piece/A11AOOOOO396202_s.jpg", "resBrand": "삼아제약(주)", "resMedicationDirection": "- 평상시 충분한 수분을 섭취하세요.\r- 전문가와 상의없이 장기간 연용하지 마세요.\r- 과도한 음주나 흡연은 삼가세요.\r- 임산부, 수유부는 투여 전 반드시 전문가와 상의하세요.", "resATCCode": "R05CA12", "resFormula": "녹색의 원형 필름코팅 정제"}, {"resNumber": "2", "resDrugCode": "663602340", "resDrugName": "프라임모사프리드정5밀리그램", "resIngredients": "mosapride citrate hydrate (as mosapride)", "resContent": "1정", "resOneDose": "1", "resDailyDosesNumber": "3", "resTotalDosingdays": "6", "resPrescribeDrugEffect":
# ...

# %%
import json
json_object = json.loads(res)
pretty_json = json.dumps(json_object, indent=4, ensure_ascii=False)
print(pretty_json)
# Out:
# {
#     "result": {
#         "code": "CF-00000",
#         "extraMessage": "",
#         "message": "성공",
#         "transactionId": "670cab29ec82b80146b46567"
#     },
#     "data": [
#         {
#             "resDrugList": [
#                 {
#                     "resNumber": "1",
#                     "resDrugCode": "645701300",
#                     "resDrugName": "헤브론에프정",
#                     "resIngredients": "ivy leaf 30% ethanol dried ext.(5~7.5→1) (as hederacoside C 2.5mg)",
#                     "resContent": "1정",
#                     "resOneDose": "1",
#                     "resDailyDosesNumber": "3",
#                     "resTotalDosingdays": "6",
#                     "resPrescribeDrugEffect": "진해거담제",
#                     "resDrugImageLink": "https://biz.kpis.or.kr/kpis_biz/images/new/piece/A11AOOOOO396202_s.jpg",
#                     "resBrand": "삼아제약(주)",
# ...
